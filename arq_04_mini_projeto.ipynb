# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_2024_1 = pd.read_csv('Preços semestrais - AUTOMOTIVOS_2024.01.csv', sep=';', decimal=',')
df_2024_2 = pd.read_csv('Preços semestrais - AUTOMOTIVOS_2024.02.csv', sep=';', decimal=',')
df_2025_1 = pd.read_csv('Preços semestrais - AUTOMOTIVOS_2025.01.csv', sep=';', decimal=',')
df_2025_2 = pd.read_csv('Preços semestrais - AUTOMOTIVOS_2025.02.csv', sep=';', decimal=',')
# Out:
# C:\Users\icaro.reboucas\AppData\Local\Temp\ipykernel_14048\2471211159.py:7: DtypeWarning: Columns (0: Regiao - Sigla, 1: Estado - Sigla, 2: Municipio, 3: Revenda, 4: CNPJ da Revenda, 5: Nome da Rua, 6: Numero Rua, 7: Complemento, 8: Bairro, 9: Cep, 10: Produto, 11: Data da Coleta, 12: Unidade de Medida, 13: Bandeira) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2025_1 = pd.read_csv('Preços semestrais - AUTOMOTIVOS_2025.01.csv', sep=';', decimal=',')

# %%
df.shape
# Out:
# (1712267, 16)

# %%
df = pd.concat([df_2024_1, df_2024_2,df_2025_1, df_2025_2],ignore_index=True)
print(df.shape)   
display(df.head(5))
display(df.tail(5))
# Out:
# (1712267, 16)
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             NE             AL  ARAPIRACA
# 1             NE             AL  ARAPIRACA
# 2             NE             AL  ARAPIRACA
# 3             NE             AL  ARAPIRACA
# 4             NE             AL  ARAPIRACA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 1  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 2  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 3  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 4                      AUTO POSTO SAO FRANCISCO LTDA   12.706.529/0001-04
#
#          Nome da Rua Numero Rua Complemento           Bairro        Cep  \
# 0     RODOVIA AL-220       1901         NaN  SANTA ESMERALDA  57312-025
# 1     RODOVIA AL-220       1901         NaN  SANTA ESMERALDA  57312-025
# 2     RODOVIA AL-220       1901         NaN  SANTA ESMERALDA  57312-025
# 3     RODOVIA AL-220       1901         NaN  SANTA ESMERALDA  57312-025
# 4  RUA SAO FRANCISCO        274         NaN           CENTRO  57300-080
#
#               Produto Data da Coleta  Valor de Venda  Valor de Compra  \
# 0            GASOLINA     01/01/2024            5.68              NaN
# 1  GASOLINA ADITIVADA     01/01/2024            5.68              NaN
# 2          DIESEL S10     01/01/2024            5.93              NaN
# 3              ETANOL     01/01/2024            3.99              NaN
# 4            GASOLINA     01/01/2024            5.48              NaN
#
#   Unidade de Medida Bandeira
# 0        R$ / litro    VIBRA
# 1        R$ / litro    VIBRA
# 2        R$ / litro    VIBRA
# 3        R$ / litro    VIBRA
# 4        R$ / litro    VIBRA
#         Regiao - Sigla Estado - Sigla   Municipio  \
# 1712262             NE             BA  ALAGOINHAS
# 1712263             NE             PB      BAYEUX
# 1712264             NE             BA      ILHEUS
# 1712265             SE             SP     JACAREI
# 1712266              S             RS     LAJEADO
#
#                                                    Revenda CNPJ da Revenda  \
# 1712262  2 A COMERCIO DE COMBUSTIVEIS GNV E LUBRIFICANT...  14238511000150
# 1712263             PETROGAS COMERCIO DE COMBUSTIVEIS LTDA  21553439000111
# 1712264  BATISTA COMERCIO DE COMBUSTIVEIS E LUBRIFICANT...  28562491000183
# 1712265                  AUTO POSTO BRANCO DE CASTELO LTDA  68912864000385
# 1712266                            SIM REDE DE POSTOS LTDA   7473735018714
#
#                      Nome da Rua Numero Rua           Complemento  \
# 1712262  RODOVIA BR 101  KM  116        S/N              SALA  01
# 1712263        AVENIDA LIBERDADE       3545   ANDAR: 1; ANEXO: A;
# 1712264      AVENIDA FERROVIARIA        S/N  KM 05 RODOVIA ILHEUS
# 1712265  AVENIDA SIQUEIRA CAMPOS        641                   NaN
# 1712266          RODOVIA ERS-130       2285            KM    72.8
#
#               Bairro        Cep Produto Data da Coleta  Valor de Venda  \
# 1712262       CENTRO  48005-440     GNV     31/12/2025            4.38
# 1712263         SESI  58306-000     GNV     31/12/2025            4.85
# 1712264       IGUAPE  45658-340     GNV     31/12/2025            4.73
# 1712265       CENTRO  12308-190     GNV     31/12/2025            3.99
# 1712266  SANTO ANDRE  95912-000     GNV     31/12/2025            5.65
#
#          Valor de Compra Unidade de Medida Bandeira
# 1712262              NaN           R$ / m3    LARCO
# 1712263              NaN           R$ / m3      ALE
# 1712264              NaN           R$ / m3   BRANCA
# 1712265              NaN           R$ / m3    VIBRA
# 1712266              NaN           R$ / m3  CHARRUA

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_produto = df.loc[df['Produto'] == 'GASOLINA']
df_produto
# Out:
#         Regiao - Sigla Estado - Sigla             Municipio  \
# 0                   NE             AL             ARAPIRACA
# 4                   NE             AL             ARAPIRACA
# 6                   NE             AL             ARAPIRACA
# 10                  NE             AL             ARAPIRACA
# 15                  NE             AL             RIO LARGO
# ...                ...            ...                   ...
# 1623419             SE             MG               JANAUBA
# 1623420              S             PR          PONTA GROSSA
# 1623421             SE             MG              ARAGUARI
# 1623422              S             PR  SAO JOSE DOS PINHAIS
# 1623423             SE             MG                VICOSA
#
#                                                    Revenda  \
# 0        COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...
# 4                            AUTO POSTO SAO FRANCISCO LTDA
# 6                             IBN PINTO E SILVA & CIA LTDA
# 10                            IBN PINTO E SILVA & CIA LTDA
# 15                                CDA EMPREENDIMENTOS LTDA
# ...                                                    ...
# 1623419           M F B NOGUEIRA POSTO DE COMBUSTIVEL LTDA
# 1623420             AUTO POSTO PROGRESSO PONTA GROSSA LTDA
# 1623421                    COMBUSTIVEIS OURO NEGRO IV LTDA
# 1623422                             POSTO LINHA VERDE LTDA
# 1623423                  WMC COMERCIO DE COMBUSTIVEIS LTDA
#
#              CNPJ da Revenda                      Nome da Rua Numero Rua  \
# 0         02.817.655/0001-82                   RODOVIA AL-220       1901
# 4         12.706.529/0001-04                RUA SAO FRANCISCO        274
# 6         01.242.690/0001-58                   RODOVIA AL-110        678
# 10        01.242.690/0002-39          AVENIDA EMIDIO DE LIMA,         23
# 15        12.486.809/0004-05         RODOVIA BR 104 AL. KM 86         SN
# ...                      ...                              ...        ...
# 1623419       32275352000227  AVENIDA MILITAO JOSE DOS SANTOS       2596
# 1623420       47536308000110       AVENIDA VISCONDE DE TAUNAY        460
# 1623421       52721170000169              AVENIDA MATO GROSSO       1740
# 1623422       38824625000736          RUA ESTELA MARI REZENDE      10789
# 1623423       52268574000149    AVENIDA JACOB LOPES DE CASTRO        920
#
#         Complemento            Bairro        Cep   Produto Data da Coleta  \
# 0               NaN   SANTA ESMERALDA  57312-025  GASOLINA     01/01/2024
# 4               NaN            CENTRO  57300-080  GASOLINA     01/01/2024
# 6          KM    70       CANAFISTULA  57302-802  GASOLINA     01/01/2024
# 10              NaN  JARDIM ESPERANCA  57307-350  GASOLINA     01/01/2024
# 15              NaN      MATA DO ROLO  57100-000  GASOLINA     01/01/2024
# ...             ...               ...        ...       ...            ...
# 1623419         NaN          PLANALTO  39445-583  GASOLINA     31/12/2025
# 1623420         NaN            CENTRO  84051-000  GASOLINA     31/12/2025
# 1623421         NaN            CENTRO  38440-046  GASOLINA     31/12/2025
# 1623422         NaN    BORDA DO CAMPO  83075-452  GASOLINA     31/12/2025
# 1623423         NaN          NOVA ERA  36574-192  GASOLINA     31/12/2025
#
#          Valor de Venda  Valor de Compra Unidade de Medida  Bandeira
# 0                  5.68              NaN        R$ / litro     VIBRA
# 4                  5.48              NaN        R$ / litro     VIBRA
# 6                  5.69              NaN        R$ / litro    BRANCA
# 10                 5.49              NaN        R$ / litro  IPIRANGA
# 15                 5.49              NaN        R$ / litro     VIBRA
# ...                 ...              ...               ...       ...
# 1623419            6.29              NaN        R$ / litro  IPIRANGA
# 1623420            6.49              NaN        R$ / litro    BRANCA
# 1623421            5.89              NaN        R$ / litro  IPIRANGA
# 1623422            6.79              NaN        R$ / litro  IPIRANGA
# 1623423            6.19              NaN        R$ / litro    BRANCA
#
# [445443 rows x 16 columns]

# %%
#df_rj = df.groupby('Estado - Sigla')['Valor de Venda'].mean().reset_index()

df_rj = df_produto.loc[df['Estado - Sigla'] == 'RJ']

df_rj.sort_values(by='Valor de Venda', ascending=False, inplace=True)

df_rj
# Out:
#         Regiao - Sigla Estado - Sigla       Municipio  \
# 629385              SE             RJ  RIO DE JANEIRO
# 1541477             SE             RJ  RIO DE JANEIRO
# 883914              SE             RJ  RIO DE JANEIRO
# 1546490             SE             RJ  RIO DE JANEIRO
# 1545135             SE             RJ  RIO DE JANEIRO
# ...                ...            ...             ...
# 69151               SE             RJ         NITEROI
# 33910               SE             RJ         NITEROI
# 2253                SE             RJ         NITEROI
# 48157               SE             RJ  RIO DE JANEIRO
# 79893               SE             RJ  RIO DE JANEIRO
#
#                                        Revenda      CNPJ da Revenda  \
# 629385             POSTO JARDIM OCEANICO LTDA.   03.317.678/0001-90
# 1541477            POSTO JARDIM OCEANICO LTDA.        3317678000190
# 883914             POSTO JARDIM OCEANICO LTDA.   03.317.678/0001-90
# 1546490            POSTO JARDIM OCEANICO LTDA.        3317678000190
# 1545135            POSTO JARDIM OCEANICO LTDA.        3317678000190
# ...                                        ...                  ...
# 69151                         POSTO ICCAR LTDA   02.280.133/0035-33
# 33910                         POSTO ICCAR LTDA   02.280.133/0035-33
# 2253                          POSTO ICCAR LTDA   02.280.133/0035-33
# 48157    POSTO DE GASOLINA JARDIM SULACAP LTDA   00.773.198/0001-46
# 79893    POSTO DE GASOLINA JARDIM SULACAP LTDA   00.773.198/0001-46
#
#                      Nome da Rua Numero Rua Complemento           Bairro  \
# 629385   AVENIDA OLEGARIO MACIEL        319         NaN  BARRA DA TIJUCA
# 1541477  AVENIDA OLEGARIO MACIEL        319         NaN  BARRA DA TIJUCA
# 883914   AVENIDA OLEGARIO MACIEL        319         NaN  BARRA DA TIJUCA
# 1546490  AVENIDA OLEGARIO MACIEL        319         NaN  BARRA DA TIJUCA
# 1545135  AVENIDA OLEGARIO MACIEL        319         NaN  BARRA DA TIJUCA
# ...                          ...        ...         ...              ...
# 69151     ALAMEDA SAO BOAVENTURA        524         NaN          FONSECA
# 33910     ALAMEDA SAO BOAVENTURA        524         NaN          FONSECA
# 2253      ALAMEDA SAO BOAVENTURA        524         NaN          FONSECA
# 48157     RUA EUZEBIO DE ALMEIDA       2098         NaN   JARDIM SULACAP
# 79893     RUA EUZEBIO DE ALMEIDA       2098         NaN   JARDIM SULACAP
#
#                Cep   Produto Data da Coleta  Valor de Venda  Valor de Compra  \
# 629385   22621-200  GASOLINA     03/09/2024            7.79              NaN
# 1541477  22621-200  GASOLINA     06/08/2025            7.79              NaN
# 883914   22621-200  GASOLINA     26/12/2024            7.79              NaN
# 1546490  22621-200  GASOLINA     18/08/2025            7.79              NaN
# 1545135  22621-200  GASOLINA     13/08/2025            7.79              NaN
# ...            ...       ...            ...             ...              ...
# 69151    24355-090  GASOLINA     25/01/2024            4.99              NaN
# 33910    24355-090  GASOLINA     11/01/2024            4.99              NaN
# 2253     24355-090  GASOLINA     02/01/2024            4.99              NaN
# 48157    22725-000  GASOLINA     17/01/2024            4.84              NaN
# 79893    22725-000  GASOLINA     30/01/2024            4.84              NaN
#
#         Unidade de Medida Bandeira
# 629385         R$ / litro   RAIZEN
# 1541477        R$ / litro   BRANCA
# 883914         R$ / litro   RAIZEN
# 1546490        R$ / litro   BRANCA
# 1545135        R$ / litro   BRANCA
# ...                   ...      ...
# 69151          R$ / litro   BRANCA
# 33910          R$ / litro   BRANCA
# 2253           R$ / litro   BRANCA
# 48157          R$ / litro   BRANCA
# 79893          R$ / litro   BRANCA
#
# [33329 rows x 16 columns]

# %%
df_media_municipio_rj = df_rj.groupby('Municipio')['Valor de Venda'].mean().reset_index()

df_media_municipio_rj.sort_values(by='Valor de Venda', ascending=False, inplace=True)

display(df_media_municipio_rj.tail(5))
# Out:
#        Municipio  Valor de Venda
# 15       NITEROI        5.757424
# 4   BELFORD ROXO        5.752965
# 12          MAGE        5.615435
# 9        ITAGUAI        5.602390
# 28   TERESOPOLIS        5.508448

# %%
plt.figure(figsize=(10, 10))
plt.barh(df_media_municipio_rj['Municipio'], df_media_municipio_rj['Valor de Venda'], color='steelblue') #cor hexadecimal buscar códigos na internet
plt.title('RJ - Municipios x Preço Médio da Gasolina')
plt.tight_layout()    
plt.show()

# %% [markdown]
# ![{9B8CD967-5220-4EBF-9A59-AA736EBD9510}.png](attachment:{9B8CD967-5220-4EBF-9A59-AA736EBD9510}.png)

# %%
array_media_municipio_rj = np.array(df_media_municipio_rj['Valor de Venda']) #array trabalha com calculos em grande volume é uma boa pratica utiliza-lo
q1 = np.percentile(array_media_municipio_rj, 25)
q2 = np.percentile(array_media_municipio_rj, 50)
q3 = np.percentile(array_media_municipio_rj, 75)

iqr = q3 - q1
limite_superior = q3 + (1.5 * iqr)
limite_inferior = q1 - (1.5 * iqr)
print(f"Limite superior: {limite_superior}")
print(f"Limite inferior: {limite_inferior}")
# Out:
# Limite superior: 7.108695331071827
# Limite inferior: 5.021890651458362

# %%
df_media_municipio_rj_outliers = df_media_municipio_rj.loc[df_media_municipio_rj['Valor de Venda'] > limite_superior]
df_media_municipio_rj_outliers = df_media_municipio_rj.loc[df_media_municipio_rj['Valor de Venda'] < limite_inferior]
df_media_municipio_rj_outliers
# Out:
# Empty DataFrame
# Columns: [Municipio, Valor de Venda]
# Index: []

# %% [markdown]
# # Não existem postos praticando preços fora do padrão, no estado do Rio de Janeiro.
# # Nesse contexto se o limite inferior fosse negativo, indicaria que não há outliers considerando o limite inferior.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_rj_sp_etanol = df.loc[(df['Estado - Sigla'].isin(['RJ','SP'])) & (df['Produto'] == 'ETANOL')] #isin = dois filtros na mesma coluna / & = utilizado para filtrar mais de uma coluna

# %%
df_media_eta_rjsp = df_rj_sp_etanol.groupby('Estado - Sigla')['Valor de Venda'].mean().reset_index()

df_media_eta_rjsp.sort_values(by='Valor de Venda', ascending=False, inplace=True)

df_media_eta_rjsp
# Out:
#   Estado - Sigla  Valor de Venda
# 0             RJ        4.434487
# 1             SP        3.896279

# %%
plt.figure(figsize=(3, 3))
plt.bar(df_media_eta_rjsp['Estado - Sigla'], df_media_eta_rjsp['Valor de Venda'], color='steelblue') #cor hexadecimal buscar códigos na internet
plt.title('Etanol - Preço Médio RJ e SP')
plt.tight_layout()    
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
