# %%
import numpy as np
import pandas as pd

dados = {
'aluno':  ['Ana','Bruno','Carol','Diego',
'Elisa','Felipe','Gabi','Hugo'],
'nota':   [8.5, 6.0, 9.2, 5.5, 7.8, 4.0, 9.0, 6.5],
'horas':  [6,   3,   8,   2,   5,   1,   7,   4  ]}

df = pd.DataFrame(dados)

# Variância das notas

variancia = np.var(df['nota'])

print(f"Variância: {variancia:.2f}")

# Saída: Variância: 3.02
# Out:
# Variância: 3.02

# %%
# Desvio padrão das notas
desvio = np.std(df['nota'])
print(f"Desvio Padrão: {desvio:.2f}")
# Saída: Desvio Padrão: 1.74
# Interpretando com a média
media = np.mean(df['nota'])
print(f"Média das notas: {media:.2f}")
print(f"Faixa típica: {media-desvio:.2f} até {media+desvio:.2f}")
# Saída:
# Média das notas: 7.06
# Faixa típica: 5.32 até 8.80
# Out:
# Desvio Padrão: 1.74
# Média das notas: 7.06
# Faixa típica: 5.32 até 8.80

# %%
matriz_cov = np.cov(df['nota'], df['horas'])
print(matriz_cov)
# [[3.46  4.48]
#  [4.48  6.00]]
# Extraindo só o valor da covariância
# Out:
# [[3.45696429 4.47857143]
#  [4.47857143 6.        ]]

# %%
cov_valor = matriz_cov[0, 1]
print(f"Covariância: {cov_valor:.2f}")
# Saída: Covariância: 4.48
# Out:
# Covariância: 4.48

# %%
# Forma alternativa com Pandas
print(df[['nota','horas']].cov())
#         nota    horas
# nota   3.456   4.479
# horas  4.479   6.000
# Out:
#            nota     horas
# nota   3.456964  4.478571
# horas  4.478571  6.000000

# %%
# Forma 1 — Pandas (mais usada na prática)
corr_pandas = df[['nota','horas']].corr()
print(corr_pandas)
#           nota     horas
# nota   
#1.0000    0.9749
# horas  0.9749    1.0000
# Out:
#            nota     horas
# nota   1.000000  0.983369
# horas  0.983369  1.000000

# %%
# Forma 2 — NumPy
r = np.corrcoef(df['nota'], df['horas']) # r força de uma relação
print(f"Pearson r = {r[0,1]:.4f}")
# Saída: Pearson r = 0.9749
# Interpretação:
# r = 0.97 → correlação MUITO FORTE positiva
# Confirma: mais horas de estudo = nota maior!
# Out:
# Pearson r = 0.9834

# %%
import numpy as np
import pandas as pd
dados = {
'aluno':  ['Ana','Bruno','Carol','Diego',
'Elisa','Felipe','Gabi','Hugo'],
'nota':   [8.5, 6.0, 9.2, 5.5, 7.8, 4.0, 9.0, 6.5],
'horas':  [6,   3,   8,   2,   5,   1,   7,   4  ]}
df = pd.DataFrame(dados)
print(f"Variância:      {np.var(df['nota']):.2f}")
print(f"Desvio Padrão:  {np.std(df['nota']):.2f}")
cov = np.cov(df['nota'], df['horas'])[0, 1]
print(f"Covariância:    {cov:.2f}")
r = np.corrcoef(df['nota'], df['horas'])[0, 1]
print(f"Pearson r:      {r:.4f}")
print("Relação: MUITO FORTE POSITIVA!")
# Out:
# Variância:      3.02
# Desvio Padrão:  1.74
# Covariância:    4.48
# Pearson r:      0.9834
# Relação: MUITO FORTE POSITIVA!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dados = 'https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv'

df = pd.read_csv(dados, encoding="latin1", sep= ';')

df.head()
# Out:
#    cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1     4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2     5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3     6    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# 4     7    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
#
#    hom_doloso  ...  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0           0  ...  NaN   NaN      21                      2
# 1           3  ...  NaN   NaN      15                      6
# 2           3  ...  NaN   NaN      47                      2
# 3           6  ...  NaN   NaN      26                      2
# 4           4  ...  NaN   NaN      10                      1
#
#    encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                 0                0                          0
# 1                 0                1                          0
# 2                 1                0                          0
# 3                 1                0                          0
# 4                 3                0                          0
#
#    pol_civis_mortos_serv  registro_ocorrencias  fase
# 0                      0                   578     3
# 1                      0                   441     3
# 2                      0                   637     3
# 3                      0                   473     3
# 4                      0                   147     3
#
# [5 rows x 65 columns]

# %% [markdown]
# ![{9FEF88DB-50EC-4301-8074-7860E41EBA47}.png](attachment:{9FEF88DB-50EC-4301-8074-7860E41EBA47}.png)

# %%
array_var = np.array(df['roubo_veiculo'])

media = np.mean(df['roubo_veiculo'])
variancia = np.var(df['roubo_veiculo'])
desvio = np.std(df['roubo_veiculo'])

print(f"Média: {media:.2f}")
print(f"Variância: {variancia:.2f}")
print(f"Desvio: {desvio:.2f}")

faixa_inferior = media - desvio
print(f'a faixa superior é {faixa_inferior}')

faixa_superior = media + desvio
print(f'a faixa superior é {faixa_superior}')

print(f"Faixa típica: {media-desvio:.2f} até {media+desvio:.2f}")
# Out:
# Média: 19.13
# Variância: 1097.19
# Desvio: 33.12
# a faixa superior é -13.996912074735754
# a faixa superior é 52.250822897338715
# Faixa típica: -14.00 até 52.25

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a_furto = np.array(df['furto_veiculo'])
